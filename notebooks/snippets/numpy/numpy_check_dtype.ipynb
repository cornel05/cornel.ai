# %% [markdown]
# # NumPy Check Data Types

# %% [markdown]
# ```python
# >>> import numpy as np
# ```

# %% [markdown]
# ```python
# >>> a = np.array([1,2], dtype=np.float32)
# >>> a.dtype == np.float32
# True
# ```

# %% [markdown]
# ```python
# >>> import numpy as np
# ```

# %% [markdown]
# ```python
# >>> a = np.array([1,2], dtype=np.float32)
# >>> a.dtype == np.float32
# True
# >>> a.dtype == np.float64
# True
# >>> a.dtype == float
# True
# >>> a.dtype == 'float64'
# True
# >>> a.dtype == 'd'
# True
# >>> a.dtype == np.int32
# False
# ```
