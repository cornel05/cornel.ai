# %% [markdown]
# # pandas:  Get specific coordinates item in the DataFrame

# %%
import pandas as pd

# %% [markdown]
# ## Loading data into Pandas DataFrame
# The dataset is from [Kaggle - Pokemon](https://www.kaggle.com/datasets/abcsds/pokemon).

# %%
data = pd.read_csv('data/Pokemon.csv')

# %%
# Get the name of the first 3 rows
item = data.iloc[[0, 1, 2], 1]
print(item)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object
