# %% [markdown]
# # pandas:  Reset index

# %%
import pandas as pd

# %% [markdown]
# ## Loading data into Pandas DataFrame
# The dataset is from [Kaggle - Pokemon](https://www.kaggle.com/datasets/abcsds/pokemon).

# %%
data = pd.read_csv('data/Pokemon.csv')

# %% [markdown]
# In the cell below, you can see the index is not consecutive (the leftmost column). We can reset it with the `reset_index()` method. By default, it adds the old index as a new column. If you do not want that, use the `drop=True` parameter.

# %%
new_data = data.loc[(data['Type 1'] == 'Grass') | (data['Type 2'] == 'Poison')][0::10].loc[data['HP'] > 50].head(3)
new_data
# Out:
#        #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 50    45  Vileplume  Grass  Poison    490  75      80       85      110
# 101   94     Gengar  Ghost  Poison    500  60      65       60      130
# 197  182  Bellossom  Grass     NaN    490  75      80       95       90
#
#      Sp. Def  Speed  Generation  Legendary
# 50        90     50           1      False
# 101       75    110           1      False
# 197      100     50           2      False

# %%
new_data.reset_index(drop=True, inplace=True)
new_data
# Out:
#      #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   45  Vileplume  Grass  Poison    490  75      80       85      110
# 1   94     Gengar  Ghost  Poison    500  60      65       60      130
# 2  182  Bellossom  Grass     NaN    490  75      80       95       90
#
#    Sp. Def  Speed  Generation  Legendary
# 0       90     50           1      False
# 1       75    110           1      False
# 2      100     50           2      False
